# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
# help(StackAPI)
from stackapi import StackAPI
from bs4 import BeautifulSoup
import requests
from time import sleep
from random import randint
import pandas as pd

# %%
SITE = StackAPI('stackoverflow')
comments = SITE.fetch('comments')
comments
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 248,
#  'total': 0,
#  'items': [{'owner': {'reputation': 1,
#     'user_id': 21680884,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/026858c5c3fa91e612e9b13275c73dd6?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'D. Boatman',
#     'link': 'https://stackoverflow.com/users/21680884/d-boatman'},
#    'reply_to_user': {'reputation': 90198,
#     'user_id': 1427878,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/db5fbf44c0eeeaf38c4e4a54ce9eff7a?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'CBroe',
#     'link': 'https://stackoverflow.com/users/1427878/cbroe'},
#    'edited': False,
#    'score': 0,
#    'creation_date': 1681908601,
#    'post_id': 76054144,
#    'comment_id': 134132463,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 21668218,
# ...

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
import requests as re
from datetime import datetime, timedelta

# %%
# your code here

settings = {
    "site": "stackoverflow",
    "pagesize": 100,
    "fromdate": int((datetime.now() - timedelta(days=30)).timestamp()),
    "todate": int(datetime.now().timestamp()),
}

response = requests.get(base_url + "questions", params=params)

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
# your code hereresponse = requests.get(base_url + 'questions', params=params)

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
# your code here
