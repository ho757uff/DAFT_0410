# %%
# IMPORT DES LIBRAIRIES
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import scipy.stats as st
import re

# %% [markdown]
# ### READ FILE

# %%
df = pd.read_excel("./4 - Salaries_Data.xlsx")

# %% [markdown]
# ### CLONING DATA

# %%
data = df

# %% [markdown]
# ### DATA TYPES

# %%
# WHAT ARE THE DIFFERENT TYPES OF DATA IN OUR DATAFRAME :
display(data.dtypes.to_frame())
# Out:
#                                0
# timestamp                 object
# company                   object
# level                     object
# title                     object
# totalyearlycompensation  float64
# location                  object
# yearsofexperience        float64
# yearsatcompany           float64
# tag                       object
# basesalary               float64
# stockgrantvalue          float64
# bonus                    float64
# gender                    object
# otherdetails              object
# cityid                     int64
# dmaid                    float64
# rowNumber                  int64
# Masters_Degree             int64
# Bachelors_Degree           int64
# Doctorate_Degree           int64
# Highschool                 int64
# Some_College             float64
# Race_Asian               float64
# Race_White               float64
# Race_Two_Or_More         float64
# Race_Black               float64
# Race_Hispanic            float64
# Race                      object
# Education                 object

# %% [markdown]
# ### NEW COLUMNS TO WORK WITH

# %%
# CREATING NEW COMPANY & TITLE COLUMN : to add new company column and delete the existing one

data['company_name'] = data['company'].str.upper()
data['title_new'] = data["title"].str.replace(r'Soft Engineer', 'Software Engineer', regex=True)

data.head(2)
# Out:
#              timestamp company    level                         title  \
# 0    7/2/2019 16:43:16   Intel  Grade 7             Hardware Engineer
# 1  10/13/2019 11:43:20   Latch  Manager  Software Engineering Manager
#
#    totalyearlycompensation         location  yearsofexperience  \
# 0                 200000.0  Santa Clara, CA               14.0
# 1                 170000.0     New York, NY                6.0
#
#    yearsatcompany              tag  basesalary  ...  Some_College  Race_Asian  \
# 0             3.0  Physical Design    163000.0  ...           0.0         1.0
# 1             2.0       Full Stack    170000.0  ...           0.0         1.0
#
#   Race_White Race_Two_Or_More  Race_Black  Race_Hispanic   Race  Education  \
# 0        0.0              0.0         0.0            0.0  Asian        NaN
# 1        0.0              0.0         0.0            0.0  Asian        NaN
#
#    company_name                     title_new
# 0         INTEL             Hardware Engineer
# 1         LATCH  Software Engineering Manager
#
# [2 rows x 31 columns]

# %% [markdown]
# ### DROPPING

# %%
# DROPPING IRRELEVANT COLUMNS OR COLUMNS WE ARE NOT USING :

dropped_data = data.drop(["title", "timestamp", "company", "Race_Asian", "Race_White", "Race_Two_Or_More","Race_Black","Race_Hispanic",
                          "Masters_Degree", "Bachelors_Degree", "Doctorate_Degree", "Highschool", "Some_College", "level"], axis=1)

dropped_data.head(2)
# Out:
#    totalyearlycompensation         location  yearsofexperience  \
# 0                 200000.0  Santa Clara, CA               14.0
# 1                 170000.0     New York, NY                6.0
#
#    yearsatcompany              tag  basesalary  stockgrantvalue    bonus  \
# 0             3.0  Physical Design    163000.0          10000.0  27000.0
# 1             2.0       Full Stack    170000.0              0.0      0.0
#
#    gender otherdetails  cityid  dmaid  rowNumber   Race Education  \
# 0  Female        Asian    7434  807.0      11381  Asian       NaN
# 1    Male        Asian   10182  501.0      16214  Asian       NaN
#
#   company_name                     title_new
# 0        INTEL             Hardware Engineer
# 1        LATCH  Software Engineering Manager

# %% [markdown]
# ### RENAMING COLUMNS

# %%
# RENAMING COLUMN NAMES FOR MORE CLARITY : 

dropped_data.rename(columns = {'totalyearlycompensation': 'total_yearly_compensation', 'yearsofexperience': 'years_of_experience', 'yearsatcompany': 'years_at_company',
                       'basesalary': 'base_salary', 'stockgrantvalue': 'stock_grant_value', 'cityid': 'city_id','rowNumber': 'row_number', 'dmaid' : 'dma_id', 'Race' : 'race', 'Education' : 'education', 'title_new' : 'title', 'otherdetails' : 'other_details'}, inplace=True)

# %% [markdown]
# ### REORDERING COLUMNS

# %%
# REORDERING OUR DATA FRAME COLUMNS TO MAKE IT MORE READABLE/EXPLOITABLE :

new_columns_order = ["row_number", "company_name", "location", "city_id", "dma_id", "years_of_experience", "years_at_company", "title", "tag", "total_yearly_compensation", "base_salary", "stock_grant_value", "bonus",
                     "gender", "race", "education", "other_details"]
reordered_data = dropped_data[new_columns_order]

reordered_data.head(2)
# Out:
#    row_number company_name         location  city_id  dma_id  \
# 0       11381        INTEL  Santa Clara, CA     7434   807.0
# 1       16214        LATCH     New York, NY    10182   501.0
#
#    years_of_experience  years_at_company                         title  \
# 0                 14.0               3.0             Hardware Engineer
# 1                  6.0               2.0  Software Engineering Manager
#
#                tag  total_yearly_compensation  base_salary  stock_grant_value  \
# 0  Physical Design                   200000.0     163000.0            10000.0
# 1       Full Stack                   170000.0     170000.0                0.0
#
#      bonus  gender   race education other_details
# 0  27000.0  Female  Asian       NaN         Asian
# 1      0.0    Male  Asian       NaN         Asian

# %% [markdown]
# ### LOCATING MISSING DATA

# %%
# # OÙ SONT LOCALISEES LES DONNEES MANQUANTES DANS NOTRE DATAFRAME ?

reordered_data.isnull().sum()

# salary_is_null = data.loc[data['base_salary'].isnull(),:]
# salary_is_null.head(10)
# Out:
# row_number                       0
# company_name                     5
# location                         3
# city_id                          0
# dma_id                           2
# years_of_experience              0
# years_at_company                 0
# title                            3
# tag                            854
# total_yearly_compensation        3
# base_salary                      1
# stock_grant_value                3
# bonus                            1
# gender                       19540
# race                         40215
# education                    32272
# otherdetails                 22505
# dtype: int64

# %% [markdown]
# ### DROPPING MISSING DATA

# %%
# MISSING VALUES ARE LESS THAN 2% OF THE REMAINING RELEVANT DATA
# SO WE ARE DROPPING THE CORRESPONDING ROWS

cleaned_data1 = reordered_data.dropna(subset=['company_name'])
cleaned_data2 = cleaned_data1.dropna(subset=['location'])
cleaned_data3 = cleaned_data2.dropna(subset=['dma_id'])
cleaned_data4 = cleaned_data3.dropna(subset=['title'])
cleaned_data5 = cleaned_data4.dropna(subset=['tag'])
cleaned_data6 = cleaned_data5.dropna(subset=['total_yearly_compensation'])
cleaned_data7 = cleaned_data6.dropna(subset=['base_salary'])
cleaned_data8 = cleaned_data7.dropna(subset=['stock_grant_value'])
cleaned_data9 = cleaned_data8.dropna(subset=['bonus'])

data = cleaned_data9

data.isnull().sum()
# Out:
# row_number                       0
# company_name                     0
# location                         0
# city_id                          0
# dma_id                           0
# years_of_experience              0
# years_at_company                 0
# title                            0
# tag                              0
# total_yearly_compensation        0
# base_salary                      0
# stock_grant_value                0
# bonus                            0
# gender                       19030
# race                         39372
# education                    31440
# otherdetails                 21792
# dtype: int64

# %% [markdown]
# ### REPLACING TYPOS

# %%
# FROM SOFT ENGINEER => SOFTWARE ENGINEER

data['title'] = data['title'].replace('Soft Engineer', 'Software Engineer')

print(data['title'].value_counts())

data
# Out:
# Software Engineer               40574
# Product Manager                  4549
# Software Engineering Manager     3519
# Data Scientist                   2573
# Hardware Engineer                2196
# Product Designer                 1513
# Technical Program Manager        1378
# Solution Architect               1156
# Management Consultant             973
# Business Analyst                  882
# Marketing                         708
# Mechanical Engineer               488
# Sales                             459
# Recruiter                         449
# Human Resources                   361
# Name: title, dtype: int64
#        row_number          company_name           location  city_id  dma_id  \
# 0           11381                 INTEL    Santa Clara, CA     7434   807.0
# 1           16214                 LATCH       New York, NY    10182   501.0
# 2           19450                INTUIT  Mountain View, CA     7322   807.0
# 3           21208                GOOGLE      Sunnyvale, CA     7472   807.0
# 4           22644               SPOTIFY       New York, NY    10182   501.0
# ...           ...                   ...                ...      ...     ...
# 62637       83871  FIDELITY INVESTMENTS         Durham, NC     9606   560.0
# 62638       39475              FACEBOOK        Seattle, WA    11527   819.0
# 62639       48059                  SNAP    Los Angeles, CA     7275   803.0
# 62640       54398              BROADCOM       San Jose, CA     7422   807.0
# 62641       62843                ZAPIER         Denver, CO     7548   751.0
#
#        years_of_experience  years_at_company                         title  \
# 0                     14.0               3.0             Hardware Engineer
# 1                      6.0               2.0  Software Engineering Manager
# 2                      1.0               1.0             Software Engineer
# 3                      5.0               5.0             Software Engineer
# 4                      8.0               2.5             Software Engineer
# ...                    ...               ...                           ...
# 62637                  0.0               0.0             Software Engineer
# 62638                 23.0               6.0  Software Engineering Manager
# 62639                  5.0               4.0  Software Engineering Manager
# 62640                 21.0               9.0                     Marketing
# 62641                 16.0               2.0  Software Engineering Manager
#
#                                   tag  total_yearly_compensation  base_salary  \
# 0                     Physical Design                   200000.0     163000.0
# 1                          Full Stack                   170000.0     170000.0
# 2         Web Development (Front-End)                   134000.0     110000.0
# 3      Distributed Systems (Back-End)                   400000.0     210000.0
# 4                          Full Stack                   210000.0     170000.0
# ...                               ...                        ...          ...
# 62637                      Full Stack                    98000.0      85000.0
# 62638                        DevInfra                  1733000.0     288000.0
# 62639                        Security                  1400000.0     235000.0
# 62640                         Product                  1470000.0     220000.0
# 62641                      Full Stack                  1605000.0     250000.0
#
#        stock_grant_value     bonus  gender   race          education  \
# 0                10000.0   27000.0  Female  Asian                NaN
# 1                    0.0       0.0    Male  Asian                NaN
# 2                13000.0   11000.0    Male  Asian                NaN
# 3               145000.0   45000.0    Male  Asian                PhD
# 4                40000.0       0.0    Male  Asian                NaN
# ...                  ...       ...     ...    ...                ...
# 62637                0.0   13000.0    Male  White                NaN
# 62638             1350.0   95000.0    Male  White  Bachelor's Degree
# 62639             1165.0       0.0    Male  White  Bachelor's Degree
# 62640             1100.0  150000.0    Male  White    Master's Degree
# 62641             1305.0   50000.0  Female  White    Master's Degree
#
#                                             otherdetails
# 0                                                  Asian
# 1                                                  Asian
# 2                                  hispanic, asian, lgbt
# 3                                            Asian - PhD
# 4                                 ethnicity: south asian
# ...                                                  ...
# 62637  10% profit share into 401k and 7% 401k match, ...
# 62638   Race: White, Academic Level: Bachelorâ€™s degree
# 62639  Title: Security Engineering Manager, Race: Whi...
# 62640  Title: Director Of Product Marketing, Race: Wh...
# 62641  Remote, Title: Vp Of Engineering, Race: White,...
#
# [61778 rows x 17 columns]

# %% [markdown]
# ## DEALING WITH OUTLIERS

# %% [markdown]
# ### METHOD 1 : TINKERING AROUND

# %%
# YEARS OF EXPERIENCE
q = data["years_of_experience"].quantile(0.99997)
p = data["years_at_company"].quantile(0.99997)
data = data[data["years_of_experience"] < q]
data = data[data["years_at_company"] < p]
data

# YEARLY COMPENSATION
a = data["total_yearly_compensation"].quantile(0.99994)
data = data[data["total_yearly_compensation"] < a]
b = data["base_salary"].quantile(0.99997)
data = data[data["base_salary"] < b]

# YEARLY BONUS
c = data["bonus"].quantile(0.99997)
data = data[data["bonus"] < c]

# %% [markdown]
# ### METHOD 2 : TRYING TO IDENTIFY THEM BY VISUALIZATION

# %%
plt.boxplot(data['total_yearly_compensation'])

plt.title('Boxplot pour Total Yearly Compensation')
plt.xlabel('Total Yearly Compensation')
plt.ylabel('Valeurs')
# Out:
# Text(0, 0.5, 'Valeurs')

# %%
plt.boxplot(data['base_salary'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2313fa3fc70>,
#   <matplotlib.lines.Line2D at 0x2313fa3ff10>],
#  'caps': [<matplotlib.lines.Line2D at 0x2313f6521f0>,
#   <matplotlib.lines.Line2D at 0x2313f652490>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2313fa3f9d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2313f652730>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2313f6529d0>],
#  'means': []}

# %% [markdown]
# ### METHOD 3 : LEARNING ABOUT .nlargest()

# %%
display(data["total_yearly_compensation"].nlargest(5))
display(data["years_of_experience"].nlargest(5))
display(data["years_at_company"].nlargest(5))
display(data["bonus"].nlargest(5))
# Out:
# 53142    2500000.0
# 12461    2372000.0
# 53152    2200000.0
# 53145    2000000.0
# 53147    1950000.0
# Name: total_yearly_compensation, dtype: float64
# 23104    42.0
# 23204    42.0
# 24551    41.0
# 24608    41.0
# 12370    40.0
# Name: years_of_experience, dtype: float64
# 21118    34.0
# 48524    34.0
# 48243    33.0
# 53077    33.0
# 36220    32.0
# Name: years_at_company, dtype: float64
# 21425    630000.0
# 12819    555000.0
# 54031    555000.0
# 19850    550000.0
# 33716    550000.0
# Name: bonus, dtype: float64

# %%
missing_values = data['total_yearly_compensation'].isnull()

missing_values
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 62637    False
# 62638    False
# 62639    False
# 62640    False
# 62641    False
# Name: total_yearly_compensation, Length: 61767, dtype: bool

# %%
# # #Average_salaries

# Business_Analyst = 103505.08
# Data_Scientist = 138054.69
# Hardware_Engineer = 139628.18 
# Human_Resources = 128590.66
# Management Consultant = 136195.7 
# Marketing = 140957.75
# Mechanical_Engineer = 118455.1 
# Product_Designer = 137188.12
# Product_Manager = 148230.71
# Recruiter = 117496.67
# Sales = 118470.72
# Software_Engineer = 132367.29
# Software_Engineering_Manager = 174007.22
# Solution Architect = 140173.51 
# Technical Program Manager = 156454.74

# %%
average_yearly_compensation = {
    'Business_Analyst': 103505.08,
    'Data_Scientist': 138054.69,
    'Hardware_Engineer': 139628.18,
    'Human_Resources': 128590.66,
    'Management Consultant': 136195.7,
    'Marketing': 140957.75,
    'Mechanical_Engineer': 118455.1,
    'Product_Designer': 137188.12,
    'Product_Manager': 148230.71,
    'Recruiter': 117496.67,
    'Sales': 118470.72,
    'Software_Engineer': 132367.29,
    'Software_Engineering_Manager': 174007.22,
    'Solution Architect': 140173.51,
    'Technical Program Manager': 156454.74
}

# WHERE ARE THE MISSING VALUES
missing_values = data['total_yearly_compensation'].isnull()

# REPLACE MISSING VALUES IN TITLES WITH CORRESPONDING SALARIES
for index, row in data[missing_values].iterrows():
    title = row['title']
    mean_salary = average_yearly_compensation.get(title)
    if mean_salary is not None:
        data.loc[index, 'total_yearly_compensation'] = mean_salary

# CHECKING IF IT WENT WELL
print(data['total_yearly_compensation'].isnull().sum())
# Out:
# 0
